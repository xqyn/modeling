# %%
105%60

# %%
 5 == 5

# %%
x = 105
y = 60

# %%
x%2 ==0

# %%
x%y

# %%
x != y

# %%
x >= y

# %%
y >= x

# %%
if x > 0:
  print('x is positive')

# %%
if x < 0:
  pass # TODO: need to handle negative values!

# %%
if x < y:
  print('x is less than y')
elif x > y:
  print('x is greater than y')
else:
  print('x and y are equal')

# %%
if x == y:
  print('x and y are equal')
else:
  if x < y:
    print('x is less than y')
  else:
    print('x is greater than y')

# %%
def countdown(n):
  if n <= 0:
    print('Blastoff!')
  else:
    print(n)
    countdown(n-1)


countdown(100)

# %%
def printntimes(s,n):
  print(s)
  if n <= 0:
    pass
  else: 
    printntimes(s,n-1)

# %%
def print_n(s, n):
  if n <= 0:
    return
  print(s)
  print_n(s, n-1)

# %%
printntimes('hello', 10)

# %%
text = input()

# %%
names = input('What...is your name?\n')

# %%
names

# %%
 y = 6

# %%
import math
signal_power = 9
noise_power = 10
ratio = signal_power//noise_power
decibels = 10 * math.log10(ratio)
print(decibels)

# %%
def countdown(n):
  while n > 0:
    print(n)
    n = n - 1
  print('Blastoff!')

# %%
countdown(4)

# %%
def sequence(n):
  while n != 1:
    print(n)
    if n % 2 == 0: # n is even
      n = n / 2
    else: # n is odd
      n = n*3 + 1

# %%
sequence(10000000000000000000)

# %%
while True:
  line = input('> ')
  if line == 'done':
    break
  print(line)
print('Done!')

# %%
a = 49
x = 8
y = (x + a/x) / 2
y

# %%
x = y
y = (x + a/x) / 2
y

# %%
import math 
math.sqrt(4)

# %%
def appx(a,x):
  import math
  while x!=math.sqrt(a):
    y = (x + a/x) / 2
    print(y)
    x = y

# %%
appx(10000,1)
# Out:
# 5000.5
# 2501.249900009999
# 1252.6239505846615
# 630.3035962394365
# 323.0844833048122
# 177.01806998329744
# 116.75473894984788
# 101.20218365353946
# 100.00714038711746
# 100.00000025490743
# 100.0

# %%
4!=3
# Out:
# True

# %%
while True:
  print(x)
  y = (x + a/x) / 2
  if y == x:
    break
  x = y
# Out:
# 7.0

# %%
epsilon
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-96-026a7c51f0ed> in <module>()
# ----> 1 epsilon
#
# NameError: name 'epsilon' is not defined
